# %% [markdown]
# # Tri-Netra Cloud Training Pipeline
# This notebook contains the complete training pipeline for the Tri-Netra models. It is designed to run on Google Colab to offload heavy dependencies and hardware constraints.

# %%
# !git clone https://github.com/YOUR_USERNAME/Tri-Netra-AI.git # Replace with your repo if private
# %cd Tri-Netra-AI
# !bash colab_setup.sh

# %% [markdown]
# ## 1. Prepare Data
# Run data preparation scripts...

# %%
# !python prepare_brats_dataset.py
# !python prepare_lgg_dataset.py

# %% [markdown]
# ## 2. Train Models
# Train models using the retrain script.

# %%
# !python retrain_classifiers_torch.py

# %% [markdown]
# ## 3. Export Weights
# The trained weights are now saved in the `artifacts/` folder. Download them and place them in the local `artifacts/` directory for use in your dashboard.

# %%
import shutil
shutil.make_archive('trained_artifacts', 'zip', 'artifacts')
from google.colab import files
files.download('trained_artifacts.zip')
